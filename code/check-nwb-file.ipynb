# %%
from pathlib import Path

from pynwb import NWBHDF5IO
from hdmf_zarr import NWBZarrIO
from nwbwidgets import nwb2widget

# %%
# %matplotlib widget

# %%
results_path = Path("../results/")

# %%
nwbfile_paths = [p for p in results_path.iterdir() if ".nwb" in p.suffixes]

# %%
nwbfile_path = nwbfile_paths[0]

# %%
if nwbfile_path.is_dir():
    io = NWBZarrIO(str(nwbfile_path), "r")
else:
    io = NWBHDF5IO(str(nwbfile_path), "r")
nwbfile = io.read()
# Out:
# /opt/conda/lib/python3.9/site-packages/pynwb/ecephys.py:90: UserWarning: ElectricalSeries 'ElectricalSeriesProbeB': The second dimension of data does not match the length of electrodes. Your data may be transposed.
#   warnings.warn("%s '%s': The second dimension of data does not match the length of electrodes. "
# /opt/conda/lib/python3.9/site-packages/pynwb/ecephys.py:90: UserWarning: ElectricalSeries 'ElectricalSeriesProbeB-LFP': The second dimension of data does not match the length of electrodes. Your data may be transposed.
#   warnings.warn("%s '%s': The second dimension of data does not match the length of electrodes. "

# %%
nwb2widget(nwbfile)
# Out:
# VBox(children=(HBox(children=(Label(value='session_description:', layout=Layout(max_height='40px', max_width='…

# %%
nwbfile.acquisition["ElectricalSeriesProbeA"].data.info
# Out:
# Name               : /acquisition/ElectricalSeriesProbeA/data
# Type               : zarr.core.Array
# Data type          : int16
# Shape              : (300000, 384)
# Chunk shape        : (78125, 64)
# Order              : C
# Read-only          : True
# Compressor         : WavPack(bps=0, dynamic_noise_shaping=True, level=3,
#                    : num_decoding_threads=8, num_encoding_threads=1,
#                    : shaping_weight=0.0)
# Store type         : zarr.storage.ConsolidatedMetadataStore
# Chunk store type   : zarr.storage.DirectoryStore
# No. bytes          : 230400000 (219.7M)
# Chunks initialized : 24/24
