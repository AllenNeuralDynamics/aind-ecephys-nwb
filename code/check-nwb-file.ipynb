# %%
from pathlib import Path
import numpy as np
from pynwb import NWBHDF5IO
from hdmf_zarr import NWBZarrIO

# %%
# %matplotlib inline

# %%
results_path = Path("../results/")

# %%
nwbfile_paths = [p for p in results_path.iterdir() if ".nwb" in p.suffixes]

# %%
nwbfile_path = nwbfile_paths[0]

# %%
if nwbfile_path.is_dir():
    io = NWBZarrIO(str(nwbfile_path), "r")
else:
    io = NWBHDF5IO(str(nwbfile_path), "r")
nwbfile = io.read()

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x140704931108320
# Fields:
#   devices: {
#     Probe A <class 'pynwb.device.Device'>,
#     Probe B <class 'pynwb.device.Device'>
#   }
#   electrode_groups: {
#     Probe A_group0 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe A_group1 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe A_group2 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe A_group3 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe B_group0 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe B_group1 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe B_group2 <class 'pynwb.ecephys.ElectrodeGroup'>,
#     Probe B_group3 <class 'pynwb.ecephys.ElectrodeGroup'>
#   }
#   electrodes: electrodes <class 'hdmf.common.table.DynamicTable'>
#   file_create_date: [datetime.datetime(2025, 10, 7, 9, 17, 13, 142344, tzinfo=tzutc())]
#   identifier: 33541f15-3ec4-4d29-a57a-22af8f8d817d
#   institution: Allen Institute for Neural Dynamics
#   processing: {
#     ecephys <class 'pynwb.base.ProcessingModule'>
#   }
#   session_description: Base NWB file generated with subject metadata
#   session_id: ecephys_800779_2025-09-26_12-57-44
#   session_start_time: 2025-09-26 12:57:44-07:00
#   subject: subject pynwb.file.Subject at 0x140704931021024
# Fields:
#   age: P173D
#   age__reference: birth
#   date_of_birth: 2025-04-06 00:00:00-07:53
#   genotype: Drd1a-Cre/wt;Adora2a-T2A-FlpO/wt;Ai233(TICL-ChRmine-TS-GFP-WPRE-ICF-CoChR-oScarlet-WPRE)-hyg/wt
#   sex: M
#   species: Mus musculus
#   subject_id: 800779
#
#   timestamps_reference_time: 2025-09-26 12:57:44-07:00

# %%
electrodes = nwbfile.electrodes.to_dataframe()

# %%
electrodes.columns
# Out:
# Index(['location', 'group', 'group_name', 'channel_name', 'rel_y',
#        'inter_sample_shift', 'gain_to_physical_unit', 'rel_x', 'physical_unit',
#        'offset_to_physical_unit'],
#       dtype='object')

# %%
electrodes.group[0]
# Out:
# Probe A_group0 pynwb.ecephys.ElectrodeGroup at 0x140705061121024
# Fields:
#   description: no description
#   device: Probe A pynwb.device.Device at 0x140705079150448
# Fields:
#   description: Model: Neuropixels 2.0 (Multi Shank) - Serial number: 20403318772
#   manufacturer: IMEC
#
#   location: unknown

# %%
nwb2widget(nwbfile)

# %%
lfpA = nwbfile.processing["ecephys"].data_interfaces["LFP"]["ElectricalSeriesProbeA-LFP"]
lfpA.electrodes.to_dataframe()[["channel_name", "group_name"]]

# %%
lfpB = nwbfile.processing["ecephys"].data_interfaces["LFP"]["ElectricalSeriesProbeB-LFP"]
lfpB.electrodes.to_dataframe()[["channel_name", "group_name"]]
